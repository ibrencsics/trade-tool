# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 2: Dividend always growing
# https://finance.yahoo.com/
# "Historical data": Time period = max, show = Dividends only, Download

# %%
stock = pd.read_csv("dividends/KO.csv", parse_dates=["Date"], index_col="Date")

# %%
stock.Dividends.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
stock["DGR"] = stock.Dividends.pct_change() * 100

# %%
stock.DGR.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Divident / free cash flow is below 75% and not growing
# https://www.morningstar.com/
# Financials / Cash flow / Export data

# %%
cash = pd.read_excel("cash_flow/KO.xls", sheet_name="KO", index_col="KO_cash-flow_Annual_As_Originally_Reported")
cash.index = cash.index.str.strip()
cash.head()
# Out:
#                                                             2018  \
# KO_cash-flow_Annual_As_Originally_Reported
# Cash Flow from Operating Activities, Indirect       7.627000e+09
# Net Cash Flow from Continuing Operating Activit...  7.320000e+09
# Cash Generated from Operating Activities            7.320000e+09
# Income/Loss before Non-Cash Adjustment              6.727000e+09
# Total Adjustments for Non-Cash Items                1.795000e+09
#
#                                                             2019  \
# KO_cash-flow_Annual_As_Originally_Reported
# Cash Flow from Operating Activities, Indirect       1.047100e+10
# Net Cash Flow from Continuing Operating Activit...  1.047100e+10
# Cash Generated from Operating Activities            1.047100e+10
# Income/Loss before Non-Cash Adjustment              8.985000e+09
# Total Adjustments for Non-Cash Items                1.120000e+09
#
#                                                             2020  \
# KO_cash-flow_Annual_As_Originally_Reported
# Cash Flow from Operating Activities, Indirect       9.844000e+09
# Net Cash Flow from Continuing Operating Activit...  9.844000e+09
# Cash Generated from Operating Activities            9.844000e+09
# Income/Loss before Non-Cash Adjustment              7.768000e+09
# Total Adjustments for Non-Cash Items                1.386000e+09
#
#                                                             2021  \
# KO_cash-flow_Annual_As_Originally_Reported
# Cash Flow from Operating Activities, Indirect       1.262500e+10
# Net Cash Flow from Continuing Operating Activit...  1.262500e+10
# Cash Generated from Operating Activities            1.262500e+10
# Income/Loss before Non-Cash Adjustment              9.804000e+09
# Total Adjustments for Non-Cash Items                1.496000e+09
#
#                                                             2022           TTM
# KO_cash-flow_Annual_As_Originally_Reported
# Cash Flow from Operating Activities, Indirect       1.101800e+10  1.110100e+10
# Net Cash Flow from Continuing Operating Activit...  1.101800e+10  1.110100e+10
# Cash Generated from Operating Activities            1.101800e+10  1.110100e+10
# Income/Loss before Non-Cash Adjustment              9.571000e+09  1.051200e+10
# Total Adjustments for Non-Cash Items                2.052000e+09  1.024000e+09

# %%
cash = cash.transpose()
cash.head()
# Out:
# KO_cash-flow_Annual_As_Originally_Reported  Cash Flow from Operating Activities, Indirect  \
# 2018                                                                         7.627000e+09
# 2019                                                                         1.047100e+10
# 2020                                                                         9.844000e+09
# 2021                                                                         1.262500e+10
# 2022                                                                         1.101800e+10
#
# KO_cash-flow_Annual_As_Originally_Reported  Net Cash Flow from Continuing Operating Activities, Indirect  \
# 2018                                                                             7.320000e+09
# 2019                                                                             1.047100e+10
# 2020                                                                             9.844000e+09
# 2021                                                                             1.262500e+10
# 2022                                                                             1.101800e+10
#
# KO_cash-flow_Annual_As_Originally_Reported  Cash Generated from Operating Activities  \
# 2018                                                                    7.320000e+09
# 2019                                                                    1.047100e+10
# 2020                                                                    9.844000e+09
# 2021                                                                    1.262500e+10
# 2022                                                                    1.101800e+10
#
# KO_cash-flow_Annual_As_Originally_Reported  Income/Loss before Non-Cash Adjustment  \
# 2018                                                                  6.727000e+09
# 2019                                                                  8.985000e+09
# 2020                                                                  7.768000e+09
# 2021                                                                  9.804000e+09
# 2022                                                                  9.571000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Total Adjustments for Non-Cash Items  \
# 2018                                                                1.795000e+09
# 2019                                                                1.120000e+09
# 2020                                                                1.386000e+09
# 2021                                                                1.496000e+09
# 2022                                                                2.052000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Depreciation, Amortization and Depletion, Non-Cash Adjustment  \
# 2018                                                                             1.086000e+09
# 2019                                                                             1.365000e+09
# 2020                                                                             1.536000e+09
# 2021                                                                             1.452000e+09
# 2022                                                                             1.260000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Depreciation and Amortization, Non-Cash Adjustment  \
# 2018                                                                             1.086000e+09
# 2019                                                                             1.365000e+09
# 2020                                                                             1.536000e+09
# 2021                                                                             1.452000e+09
# 2022                                                                             1.260000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Stock-Based Compensation, Non-Cash Adjustment  \
# 2018                                                                          225000000.0
# 2019                                                                          201000000.0
# 2020                                                                          126000000.0
# 2021                                                                          337000000.0
# 2022                                                                          356000000.0
#
# KO_cash-flow_Annual_As_Originally_Reported  Deferred Taxes, Non-Cash Adjustment  \
# 2018                                                               -450000000.0
# 2019                                                               -280000000.0
# 2020                                                                -18000000.0
# 2021                                                                894000000.0
# 2022                                                               -122000000.0
#
# KO_cash-flow_Annual_As_Originally_Reported  Net Investment Income/Loss, Non-Cash Adjustment  \
# 2018                                                                           -495000000.0
# 2019                                                                           -330000000.0
# 2020                                                                           -599000000.0
# 2021                                                                           -529000000.0
# 2022                                                                           -635000000.0
#
# KO_cash-flow_Annual_As_Originally_Reported  ...  Common Stock Dividends Paid  \
# 2018                                        ...                -6.644000e+09
# 2019                                        ...                -6.845000e+09
# 2020                                        ...                -7.047000e+09
# 2021                                        ...                -7.252000e+09
# 2022                                        ...                -7.616000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Other Financing Cash Flow  \
# 2018                                                    -2.430000e+08
# 2019                                                    -2.270000e+08
# 2020                                                     3.100000e+08
# 2021                                                    -3.530000e+08
# 2022                                                    -1.095000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Net Cash Flow from Discontinuing Financing Activities  \
# 2018                                                                              205000000.0
# 2019                                                                                      NaN
# 2020                                                                                      NaN
# 2021                                                                                      NaN
# 2022                                                                                      NaN
#
# KO_cash-flow_Annual_As_Originally_Reported  Cash and Cash Equivalents, End of Period  \
# 2018                                                                    9.318000e+09
# 2019                                                                    6.737000e+09
# 2020                                                                    7.110000e+09
# 2021                                                                    1.002500e+10
# 2022                                                                    9.825000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Change in Cash  \
# 2018                                          3.207000e+09
# 2019                                         -2.509000e+09
# 2020                                          2.970000e+08
# 2021                                          3.074000e+09
# 2022                                          5.000000e+06
#
# KO_cash-flow_Annual_As_Originally_Reported  Effect of Exchange Rate Changes  \
# 2018                                                           -262000000.0
# 2019                                                            -72000000.0
# 2020                                                             76000000.0
# 2021                                                           -159000000.0
# 2022                                                           -205000000.0
#
# KO_cash-flow_Annual_As_Originally_Reported  Cash and Cash Equivalents, Beginning of Period  \
# 2018                                                                          6.373000e+09
# 2019                                                                          9.318000e+09
# 2020                                                                          6.737000e+09
# 2021                                                                          7.110000e+09
# 2022                                                                          1.002500e+10
#
# KO_cash-flow_Annual_As_Originally_Reported  Cash Flow Supplemental Section  \
# 2018                                                                   NaN
# 2019                                                                   NaN
# 2020                                                                   NaN
# 2021                                                                   NaN
# 2022                                                                   NaN
#
# KO_cash-flow_Annual_As_Originally_Reported  Change in Cash as Reported, Supplemental  \
# 2018                                                                    2.945000e+09
# 2019                                                                   -2.581000e+09
# 2020                                                                    3.730000e+08
# 2021                                                                    2.915000e+09
# 2022                                                                   -2.000000e+08
#
# KO_cash-flow_Annual_As_Originally_Reported  Fiscal year ends in Dec 31 | USD
# 2018                                                                     NaN
# 2019                                                                     NaN
# 2020                                                                     NaN
# 2021                                                                     NaN
# 2022                                                                     NaN
#
# [5 rows x 62 columns]

# %%
#cash.columns.tolist()

# %%
#cash[["Cash Flow from Operating Activities, Indirect", "            Cash Dividends Paid", "        Capital Expenditure, Reported"]]

# %%
cash = cash.rename(columns={"Cash Flow from Operating Activities, Indirect": "operating"})
cash = cash.rename(columns={"Cash Dividends Paid": "dividends_paid"})
cash = cash.rename(columns={"Capital Expenditure, Reported": "capex"})
cash.head()
# Out:
# KO_cash-flow_Annual_As_Originally_Reported     operating  \
# 2018                                        7.627000e+09
# 2019                                        1.047100e+10
# 2020                                        9.844000e+09
# 2021                                        1.262500e+10
# 2022                                        1.101800e+10
#
# KO_cash-flow_Annual_As_Originally_Reported  Net Cash Flow from Continuing Operating Activities, Indirect  \
# 2018                                                                             7.320000e+09
# 2019                                                                             1.047100e+10
# 2020                                                                             9.844000e+09
# 2021                                                                             1.262500e+10
# 2022                                                                             1.101800e+10
#
# KO_cash-flow_Annual_As_Originally_Reported  Cash Generated from Operating Activities  \
# 2018                                                                    7.320000e+09
# 2019                                                                    1.047100e+10
# 2020                                                                    9.844000e+09
# 2021                                                                    1.262500e+10
# 2022                                                                    1.101800e+10
#
# KO_cash-flow_Annual_As_Originally_Reported  Income/Loss before Non-Cash Adjustment  \
# 2018                                                                  6.727000e+09
# 2019                                                                  8.985000e+09
# 2020                                                                  7.768000e+09
# 2021                                                                  9.804000e+09
# 2022                                                                  9.571000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Total Adjustments for Non-Cash Items  \
# 2018                                                                1.795000e+09
# 2019                                                                1.120000e+09
# 2020                                                                1.386000e+09
# 2021                                                                1.496000e+09
# 2022                                                                2.052000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Depreciation, Amortization and Depletion, Non-Cash Adjustment  \
# 2018                                                                             1.086000e+09
# 2019                                                                             1.365000e+09
# 2020                                                                             1.536000e+09
# 2021                                                                             1.452000e+09
# 2022                                                                             1.260000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Depreciation and Amortization, Non-Cash Adjustment  \
# 2018                                                                             1.086000e+09
# 2019                                                                             1.365000e+09
# 2020                                                                             1.536000e+09
# 2021                                                                             1.452000e+09
# 2022                                                                             1.260000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Stock-Based Compensation, Non-Cash Adjustment  \
# 2018                                                                          225000000.0
# 2019                                                                          201000000.0
# 2020                                                                          126000000.0
# 2021                                                                          337000000.0
# 2022                                                                          356000000.0
#
# KO_cash-flow_Annual_As_Originally_Reported  Deferred Taxes, Non-Cash Adjustment  \
# 2018                                                               -450000000.0
# 2019                                                               -280000000.0
# 2020                                                                -18000000.0
# 2021                                                                894000000.0
# 2022                                                               -122000000.0
#
# KO_cash-flow_Annual_As_Originally_Reported  Net Investment Income/Loss, Non-Cash Adjustment  \
# 2018                                                                           -495000000.0
# 2019                                                                           -330000000.0
# 2020                                                                           -599000000.0
# 2021                                                                           -529000000.0
# 2022                                                                           -635000000.0
#
# KO_cash-flow_Annual_As_Originally_Reported  ...  Common Stock Dividends Paid  \
# 2018                                        ...                -6.644000e+09
# 2019                                        ...                -6.845000e+09
# 2020                                        ...                -7.047000e+09
# 2021                                        ...                -7.252000e+09
# 2022                                        ...                -7.616000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Other Financing Cash Flow  \
# 2018                                                    -2.430000e+08
# 2019                                                    -2.270000e+08
# 2020                                                     3.100000e+08
# 2021                                                    -3.530000e+08
# 2022                                                    -1.095000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Net Cash Flow from Discontinuing Financing Activities  \
# 2018                                                                              205000000.0
# 2019                                                                                      NaN
# 2020                                                                                      NaN
# 2021                                                                                      NaN
# 2022                                                                                      NaN
#
# KO_cash-flow_Annual_As_Originally_Reported  Cash and Cash Equivalents, End of Period  \
# 2018                                                                    9.318000e+09
# 2019                                                                    6.737000e+09
# 2020                                                                    7.110000e+09
# 2021                                                                    1.002500e+10
# 2022                                                                    9.825000e+09
#
# KO_cash-flow_Annual_As_Originally_Reported  Change in Cash  \
# 2018                                          3.207000e+09
# 2019                                         -2.509000e+09
# 2020                                          2.970000e+08
# 2021                                          3.074000e+09
# 2022                                          5.000000e+06
#
# KO_cash-flow_Annual_As_Originally_Reported  Effect of Exchange Rate Changes  \
# 2018                                                           -262000000.0
# 2019                                                            -72000000.0
# 2020                                                             76000000.0
# 2021                                                           -159000000.0
# 2022                                                           -205000000.0
#
# KO_cash-flow_Annual_As_Originally_Reported  Cash and Cash Equivalents, Beginning of Period  \
# 2018                                                                          6.373000e+09
# 2019                                                                          9.318000e+09
# 2020                                                                          6.737000e+09
# 2021                                                                          7.110000e+09
# 2022                                                                          1.002500e+10
#
# KO_cash-flow_Annual_As_Originally_Reported  Cash Flow Supplemental Section  \
# 2018                                                                   NaN
# 2019                                                                   NaN
# 2020                                                                   NaN
# 2021                                                                   NaN
# 2022                                                                   NaN
#
# KO_cash-flow_Annual_As_Originally_Reported  Change in Cash as Reported, Supplemental  \
# 2018                                                                    2.945000e+09
# 2019                                                                   -2.581000e+09
# 2020                                                                    3.730000e+08
# 2021                                                                    2.915000e+09
# 2022                                                                   -2.000000e+08
#
# KO_cash-flow_Annual_As_Originally_Reported  Fiscal year ends in Dec 31 | USD
# 2018                                                                     NaN
# 2019                                                                     NaN
# 2020                                                                     NaN
# 2021                                                                     NaN
# 2022                                                                     NaN
#
# [5 rows x 62 columns]

# %%
cash = cash[["operating", "dividends_paid", "capex"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 cash = cash[["operating", "dividends_paid", "capex"]]
#
# File ~/anaconda3/envs/pandas_in_action/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/pandas_in_action/lib/python3.11/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/envs/pandas_in_action/lib/python3.11/site-packages/pandas/core/indexes/base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['capex'] not in index"

# %%
cash["free_cash_flow"] = cash["operating"] + cash["capex"]
cash["div_per_cash"] = (cash["dividends_paid"] / cash["free_cash_flow"]) * 100 * (-1)

# %%
cash
# Out:
# PG_cash-flow_Annual_As_Originally_Reported     operating  dividends_paid  \
# 2019                                        1.524200e+10   -7.498000e+09
# 2020                                        1.740300e+10   -7.789000e+09
# 2021                                        1.837100e+10   -8.263000e+09
# 2022                                        1.672300e+10   -8.770000e+09
# 2023                                        1.684800e+10   -8.999000e+09
# TTM                                         1.684800e+10   -8.999000e+09
#
# PG_cash-flow_Annual_As_Originally_Reported         capex  free_cash_flow  \
# 2019                                       -3.347000e+09    1.189500e+10
# 2020                                       -3.073000e+09    1.433000e+10
# 2021                                       -2.787000e+09    1.558400e+10
# 2022                                       -3.156000e+09    1.356700e+10
# 2023                                       -3.062000e+09    1.378600e+10
# TTM                                        -3.062000e+09    1.378600e+10
#
# PG_cash-flow_Annual_As_Originally_Reported  div_per_cash
# 2019                                           63.034889
# 2020                                           54.354501
# 2021                                           53.022331
# 2022                                           64.642146
# 2023                                           65.276367
# TTM                                            65.276367
